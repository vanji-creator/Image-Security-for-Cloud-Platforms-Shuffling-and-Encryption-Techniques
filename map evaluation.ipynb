# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to evaluate Arnold's Cat Map
def arnold_cat_map(x, y, iterations):
    for _ in range(iterations):
        x, y = (2 * x + y) % width, (x + y) % height
    return x, y

# Function to evaluate Tinkerbell Map
def tinkerbell_map(x, y, a, b, c, d, iterations):
    x_vals = [x]
    y_vals = [y]
    for _ in range(iterations):
        x_new = x**4 - y**2 + a * x + b * y
        y_new = 2 * x * y + c * x + d * y
        x, y = x_new, y_new
        x_vals.append(x)
        y_vals.append(y)
    return x_vals, y_vals

# Function to evaluate Lozi Map
def lozi_map(x, y, a, b, iterations):
    x_vals = [x]
    y_vals = [y]
    for _ in range(iterations):
        x_new = 1 - abs(y - a * x) 
        y_new = b * x
        x, y = x_new, y_new
        x_vals.append(x)
        y_vals.append(y)
    return x_vals, y_vals

# Parameters
width = 100
height = 100
iterations = 10000
a_tinkerbell = 0.9
b_tinkerbell = -0.6013
c_tinkerbell = 2.0
d_tinkerbell = 0.5
a_lozi = 1.5
b_lozi = 0.5

# Initial conditions
x0 = 0.1
y0 = 0.1

# Evaluate maps
x_vals_arnold = []
y_vals_arnold = []
x_vals_tinkerbell, y_vals_tinkerbell = tinkerbell_map(x0, y0, a_tinkerbell, b_tinkerbell, c_tinkerbell, d_tinkerbell, iterations)
x_vals_lozi, y_vals_lozi = lozi_map(x0, y0, a_lozi, b_lozi, iterations)

# Plot attractor phase diagrams
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.title("Tinkerbell Map Attractor")
plt.plot(x_vals_tinkerbell, y_vals_tinkerbell, '.', markersize=1)
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1, 2, 2)
plt.title("Lozi Map Attractor")
plt.plot(x_vals_lozi, y_vals_lozi, '.', markersize=1)
plt.xlabel("x")
plt.ylabel("y")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to evaluate Tinkerbell Map
def tinkerbell_map(x, y, a, b, c, d, iterations):
    x_vals = [x]
    y_vals = [y]
    for _ in range(iterations):
        x_new = x**2 - y**2 + a * x + b * y
        y_new = 2 * x * y + c * x + d * y
        x, y = x_new, y_new
        x_vals.append(x)
        y_vals.append(y)
    return x_vals, y_vals

# Function to evaluate Modified Tinkerbell Map
def novel_tinkerbell_map(x, y, a, b, c, d, iterations):
    x_vals = [x]
    y_vals = [y]
    for _ in range(iterations):
        x_new = x**4 - y**2 + a * x + b * y # Small adjustment here
        y_new = 2 * x * y + c * x + d * y
        x, y = x_new, y_new
        x_vals.append(x)
        y_vals.append(y)
    return x_vals, y_vals


# Parameters
iterations = 10000
a_tinkerbell = 0.9
b_tinkerbell = -0.6013
c_tinkerbell = 2.0
d_tinkerbell = 0.5

# Initial conditions
x0 = 0.1
y0 = 0.1

# Evaluate maps
x_vals_tinkerbell, y_vals_tinkerbell = tinkerbell_map(x0, y0, a_tinkerbell, b_tinkerbell, c_tinkerbell, d_tinkerbell, iterations)
x_vals_novel_tinkerbell, y_vals_novel_tinkerbell = novel_tinkerbell_map(x0, y0, a_tinkerbell, b_tinkerbell, c_tinkerbell, d_tinkerbell, iterations)

# Plot attractor phase diagrams
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title("Original Tinkerbell Map Attractor")
plt.plot(x_vals_tinkerbell, y_vals_tinkerbell, '.', markersize=1)
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1, 2, 2)
plt.title("Modified Tinkerbell Map Attractor")
plt.plot(x_vals_novel_tinkerbell, y_vals_novel_tinkerbell, '.', markersize=1)
plt.xlabel("x")
plt.ylabel("y")

plt.tight_layout()
plt.show()
